# %% [markdown]
# # 0. Experiment Design
#
# - Task: single-label food image classification
# - Datasets:
#     Food-101 (for baseline comparison with most other projects),
#     FoodSG233 (local context)
# - Fix comparison constraints:
#   - Input resolution (e.g., 224×224)
#   - Training budget (epochs or steps)
#   - Optimizer family (e.g., AdamW)
#   - Augmentation policy
#   - Evaluation metrics (Top-1, Macro-F1)
#   - Random seeds

# %% [markdown]
# # 1. Dataset Preparation

# %%
from datasets import load_dataset

food101_ds = load_dataset("ethz/food101")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from datasets import load_dataset
#       3 food101_ds = load_dataset("ethz/food101")
#
# ModuleNotFoundError: No module named 'datasets'
